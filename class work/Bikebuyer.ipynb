# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
data = pd.read_csv('bikebuyer1.csv')

# %%
data
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
data['Yearly Income'].min()
# Out:
# 0

# %%
data['Yearly Income'].max()
# Out:
# 170000

# %%
data['Yearly Income'].mean()
# Out:
# 57020.151493497215

# %%
data['Yearly Income'].median()
# Out:
# 60000.0

# %%
data['Yearly Income'].mode()
# Out:
# 0    60000
# dtype: int64

# %%
np.std(data['Yearly Income'])
# Out:
# 32078.15719490367

# %%
np.var(data['Yearly Income'])
# Out:
# 1029008169.0209501

# %%
data['Gender'].count()
# Out:
# 6968

# %%
data['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
# getting the count of missing values
data.apply(lambda x : sum(x.isnull()),axis = 0)
# Out:
# ID                   1
# Marital Status      16
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data['Marital Status'].value_counts()
# Out:
# Married    4133
# Single     2848
# Name: Marital Status, dtype: int64

# %%
data['Marital Status'].fillna('Married',inplace = True)
data['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
data['Gender'].fillna('Male',inplace= True)

# %%
data['Gender'].value_counts()
# Out:
# Male      3556
# Female    3441
# Name: Gender, dtype: int64

# %%
data.apply(lambda x : sum(x.isnull()),axis = 0)
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data['Children'].fillna(data['Children'].mean(),inplace = True)

# %%
data['Commute Distance'].fillna(data['Commute Distance'].mean(),inplace= True )

# %%
data.apply(lambda x : sum(x.isnull()),axis = 0)
# Out:
# ID                  1
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
data = data.drop(['ID'],axis = 1 )

# %%
data
# Out:
#      Marital Status  Gender  Yearly Income  Children            Education  \
# 0            Single    Male          30000  0.000000      Partial College
# 1           Married  Female          40000  0.000000      Graduate Degree
# 2           Married    Male         160000  5.000000      Partial College
# 3            Single    Male         160000  0.000000      Graduate Degree
# 4           Married  Female          70000  2.000000            Bachelors
# 5           Married    Male         120000  2.000000            Bachelors
# 6            Single  Female          70000  0.000000          High School
# 7            Single  Female          60000  0.000000          High School
# 8           Married  Female              0  1.111621            Bachelors
# 9            Single  Female          20000  1.000000      Partial College
# 10           Single    Male          50000  0.000000            Bachelors
# 11          Married  Female          70000  2.000000      Partial College
# ...

# %%
data.describe()
# Out:
#        Yearly Income     Children         Cars  Commute Distance          Age
# count    6997.000000  6997.000000  6997.000000       6997.000000  6997.000000
# mean    57020.151493     1.111621     1.586823          4.210103    45.107332
# std     32080.449720     1.598851     1.146782          2.920140    11.916654
# min         0.000000     0.000000     0.000000          1.000000    25.000000
# 25%     30000.000000     0.000000     1.000000          1.000000    36.000000
# 50%     60000.000000     0.000000     2.000000          4.000000    44.000000
# 75%     70000.000000     2.000000     2.000000          6.000000    53.000000
# max    170000.000000     5.000000     4.000000         13.000000    96.000000

# %%
data.cov()   # covarience
# Out:
#                   Yearly Income      Children          Cars  Commute Distance  \
# Yearly Income      1.029155e+09  24317.621655  17367.818463        885.257378
# Children           2.431762e+04      2.556325      0.821075          0.122652
# Cars               1.736782e+04      0.821075      1.315109          0.061493
# Commute Distance   8.852574e+02      0.122652      0.061493          8.527217
# Age                7.468094e+04     -0.009904      1.928144         -0.907004
#
#                            Age
# Yearly Income     74680.941428
# Children             -0.009904
# Cars                  1.928144
# Commute Distance     -0.907004
# Age                 142.006631

# %%
data.corr()   # correlation
# Out:
#                   Yearly Income  Children      Cars  Commute Distance  \
# Yearly Income          1.000000  0.474103  0.472089          0.009450
# Children               0.474103  1.000000  0.447810          0.026270
# Cars                   0.472089  0.447810  1.000000          0.018363
# Commute Distance       0.009450  0.026270  0.018363          1.000000
# Age                    0.195351 -0.000520  0.141093         -0.026065
#
#                        Age
# Yearly Income     0.195351
# Children         -0.000520
# Cars              0.141093
# Commute Distance -0.026065
# Age               1.000000

# %%
# create a data Frame

# %%
import matplotlib as plt
# %matplotlib inline

# %%
data['Age'].hist(bins=300)

# %%
data.boxplot(column = 'Yearly Income')

# %%
data.boxplot(column = 'Commute Distance')

# %%
data.boxplot(column = 'Cars')

# %%
data.boxplot(column = 'Children')

# %%
# histographic representation
# boxplot representaioon

# %%
#preprocessing  of data
data.shape
# Out:
# (6997, 12)

# %%
x = data.iloc[:,0:-1].values
y = data.iloc[:,-1].values

# %%
x
# Out:
# array([['Single', 'Male', 30000, ..., 1.0, 'Europe', 33],
#        ['Married', 'Female', 40000, ..., 1.0, 'Europe', 37],
#        ['Married', 'Male', 160000, ..., 2.0, 'Europe', 55],
#        ...,
#        ['Married', 'Female', 160000, ..., 1.0, 'Europe', 53],
#        ['Single', 'Female', 120000, ..., 1.0, 'Europe', 54],
#        ['Married', 'Male', 130000, ..., 2.0, 'Europe', 54]], dtype=object)

# %%
y
# Out:
# array(['Yes', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
# encode the independent variable state 
from sklearn.preprocessing import LabelEncoder ,OneHotEncoder 
labelencoder_x = LabelEncoder()
x[:,0] = labelencoder_x.fit_transform(x[:,0])
x[:,1] = labelencoder_x.fit_transform(x[:,1])
x[:,4] = labelencoder_x.fit_transform(x[:,4])
x[:,5] = labelencoder_x.fit_transform(x[:,5])
x[:,6] = labelencoder_x.fit_transform(x[:,6])
x[:,9] = labelencoder_x.fit_transform(x[:,9])

# %%
x
# Out:
# array([[1, 1, 30000, ..., 1.0, 0, 33],
#        [0, 0, 40000, ..., 1.0, 0, 37],
#        [0, 1, 160000, ..., 2.0, 0, 55],
#        ...,
#        [0, 0, 160000, ..., 1.0, 0, 53],
#        [1, 0, 120000, ..., 1.0, 0, 54],
#        [0, 1, 130000, ..., 2.0, 0, 54]], dtype=object)

# %%
# apply normalization to restore the features to a standard range of values 
# normalize the numeric variables from the cloumn 1 to 10 in the data
from sklearn import preprocessing
minmax = preprocessing.MinMaxScaler(feature_range = (0,1))
minmax.fit(x).transform(x)
# Out:
# C:\ml\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[1.        , 1.        , 0.17647059, ..., 0.        , 0.        ,
#         0.11267606],
#        [0.        , 0.        , 0.23529412, ..., 0.        , 0.        ,
#         0.16901408],
#        [0.        , 1.        , 0.94117647, ..., 0.08333333, 0.        ,
#         0.42253521],
#        ...,
#        [0.        , 0.        , 0.94117647, ..., 0.        , 0.        ,
#         0.3943662 ],
#        [1.        , 0.        , 0.70588235, ..., 0.        , 0.        ,
#         0.4084507 ],
#        [0.        , 1.        , 0.76470588, ..., 0.08333333, 0.        ,
#         0.4084507 ]])

# %%
# stats model
# OLS method
