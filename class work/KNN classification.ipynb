# %%
# Out:
# C:\Users\prade\Desktop\data_sets

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
data1 = pd.read_csv('data.csv')

# %%
data1
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
# drop the first coulmum as its an idnetifier 
data1 = data1.drop(['id'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f3247cd0b8d3> in <module>()
#       1 # drop the first coulmum as its an idnetifier
# ----> 2 data1 = data1.drop(['id'],axis=1)
#
# C:\ml\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# C:\ml\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
# ...

# %%
data1
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M       17.990         10.38          122.80     1001.0
# 1           M       20.570         17.77          132.90     1326.0
# 2           M       19.690         21.25          130.00     1203.0
# 3           M       11.420         20.38           77.58      386.1
# 4           M       20.290         14.34          135.10     1297.0
# 5           M       12.450         15.70           82.57      477.1
# 6           M       18.250         19.98          119.60     1040.0
# 7           M       13.710         20.83           90.20      577.9
# 8           M       13.000         21.82           87.50      519.8
# 9           M       12.460         24.04           83.97      475.9
# 10          M       16.020         23.24          102.70      797.8
# 11          M       15.780         17.89          103.60      781.0
# 12          M       19.170         24.80          132.40     1123.0
# ...

# %%
# Examine the target varible diagnosis which is the variable to predict 
# get a count of diagnosis observation by type 
data1.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# recode the target variable diagnosis to conatin the label 'malignant'  and 'Benign'
data1['diagnosis'].replace(['M','B'],['Malignant','Benign'],inplace = True)

# %%
data1
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    Malignant       17.990         10.38          122.80     1001.0
# 1    Malignant       20.570         17.77          132.90     1326.0
# 2    Malignant       19.690         21.25          130.00     1203.0
# 3    Malignant       11.420         20.38           77.58      386.1
# 4    Malignant       20.290         14.34          135.10     1297.0
# 5    Malignant       12.450         15.70           82.57      477.1
# 6    Malignant       18.250         19.98          119.60     1040.0
# 7    Malignant       13.710         20.83           90.20      577.9
# 8    Malignant       13.000         21.82           87.50      519.8
# 9    Malignant       12.460         24.04           83.97      475.9
# 10   Malignant       16.020         23.24          102.70      797.8
# 11   Malignant       15.780         17.89          103.60      781.0
# 12   Malignant       19.170         24.80          132.40     1123.0
# ...

# %%
# get summary of paarameters 
x = data1.loc[:,['radius_mean','area_mean','smoothness_mean']]

# %%
x.describe()
# Out:
#        radius_mean    area_mean  smoothness_mean
# count   569.000000   569.000000       569.000000
# mean     14.127292   654.889104         0.096360
# std       3.524049   351.914129         0.014064
# min       6.981000   143.500000         0.052630
# 25%      11.700000   420.300000         0.086370
# 50%      13.370000   551.100000         0.095870
# 75%      15.780000   782.700000         0.105300
# max      28.110000  2501.000000         0.163400

# %%
x = data1.iloc[:,1:31]
y=data1.iloc[:,0]

# %%
x   # divided the data into random
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         17.990         10.38          122.80     1001.0          0.11840
# 1         20.570         17.77          132.90     1326.0          0.08474
# 2         19.690         21.25          130.00     1203.0          0.10960
# 3         11.420         20.38           77.58      386.1          0.14250
# 4         20.290         14.34          135.10     1297.0          0.10030
# 5         12.450         15.70           82.57      477.1          0.12780
# 6         18.250         19.98          119.60     1040.0          0.09463
# 7         13.710         20.83           90.20      577.9          0.11890
# 8         13.000         21.82           87.50      519.8          0.12730
# 9         12.460         24.04           83.97      475.9          0.11860
# 10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
y
# Out:
# 0      Malignant
# 1      Malignant
# 2      Malignant
# 3      Malignant
# 4      Malignant
# 5      Malignant
# 6      Malignant
# 7      Malignant
# 8      Malignant
# 9      Malignant
# 10     Malignant
# 11     Malignant
# 12     Malignant
# 13     Malignant
# 14     Malignant
# 15     Malignant
# 16     Malignant
# 17     Malignant
# 18     Malignant
# 19        Benign
# 20        Benign
# 21        Benign
# 22     Malignant
# 23     Malignant
# 24     Malignant
# 25     Malignant
# 26     Malignant
# 27     Malignant
# 28     Malignant
# 29     Malignant
#          ...
# 539       Benign
# 540       Benign
# 541       Benign
# 542       Benign
# 543       Benign
# 544       Benign
# 545       Benign
# 546       Benign
# 547       Benign
# 548       Benign
# 549       Benign
# 550       Benign
# 551       Benign
# 552       Benign
# 553       Benign
# 554       Benign
# 555       Benign
# 556       Benign
# 557       Benign
# 558       Benign
# 559       Benign
# ...

# %%
# apply mormalization to rescle the fetures to a standard range of values 
#normalize the numeric variables form the column2 to column 31 in the data
minmax = preprocessing.MinMaxScaler(feature_range = (0,1))
minmax.fit(x).transform(x)
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.91202749, 0.59846245,
#         0.41886396],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
# after preprocessing slpitting th e va;ues ot train and test dtaa
from sklearn import cross_validation , neighbors
from sklearn.cross_validation import train_test_split
x_train , x_test ,y_train,y_test = train_test_split(x,y,test_size=0.2)
# when the statistical behavioour is abnormal then go for normalization
# Out:
# C:\ml\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 233       20.510         27.81          134.40     1319.0          0.09159
# 197       18.080         21.84          117.40     1024.0          0.07371
# 81        13.340         15.86           86.49      520.0          0.10780
# 50        11.760         21.60           74.72      427.9          0.08637
# 111       12.630         20.76           82.15      480.4          0.09933
# 461       27.420         26.27          186.90     2501.0          0.10840
# 405       10.940         18.59           70.39      370.0          0.10040
# 434       14.860         16.94           94.89      673.7          0.08924
# 274       17.930         24.48          115.20      998.9          0.08855
# 418       12.700         12.17           80.88      495.0          0.08785
# 163       12.340         22.22           79.85      464.5          0.10120
# ...

# %%
y_train
# Out:
# 233    Malignant
# 197    Malignant
# 81        Benign
# 50        Benign
# 111       Benign
# 461    Malignant
# 405       Benign
# 434       Benign
# 274    Malignant
# 418       Benign
# 163       Benign
# 27     Malignant
# 143       Benign
# 241       Benign
# 139       Benign
# 496       Benign
# 166       Benign
# 53     Malignant
# 353    Malignant
# 324       Benign
# 195       Benign
# 23     Malignant
# 469       Benign
# 183       Benign
# 79        Benign
# 246       Benign
# 362       Benign
# 549       Benign
# 4      Malignant
# 369    Malignant
#          ...
# 527       Benign
# 221       Benign
# 294       Benign
# 271       Benign
# 232       Benign
# 510       Benign
# 464       Benign
# 131    Malignant
# 80        Benign
# 431       Benign
# 511       Benign
# 385    Malignant
# 129    Malignant
# 59        Benign
# 407       Benign
# 566    Malignant
# 228       Benign
# 438       Benign
# 402       Benign
# 3      Malignant
# 295       Benign
# ...

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 89        14.640         15.24           95.77      651.9          0.11320
# 485       12.450         16.41           82.85      476.7          0.09514
# 283       16.240         18.77          108.80      805.1          0.10660
# 154       13.150         15.34           85.31      538.9          0.09384
# 222       10.180         17.53           65.12      313.1          0.10610
# 264       17.190         22.07          111.60      928.3          0.09726
# 425       10.030         21.28           63.19      307.3          0.08117
# 100       13.610         24.98           88.05      582.7          0.09488
# 447       14.800         17.66           95.88      674.8          0.09179
# 389       19.550         23.21          128.90     1174.0          0.10100
# 309       13.050         13.84           82.71      530.6          0.08352
# ...

# %%
y_test
# Out:
# 89        Benign
# 485       Benign
# 283    Malignant
# 154       Benign
# 222       Benign
# 264    Malignant
# 425       Benign
# 100    Malignant
# 447       Benign
# 389    Malignant
# 309       Benign
# 196    Malignant
# 49        Benign
# 130       Benign
# 259    Malignant
# 374       Benign
# 303       Benign
# 358       Benign
# 326       Benign
# 296       Benign
# 185       Benign
# 116       Benign
# 182    Malignant
# 201    Malignant
# 299       Benign
# 345       Benign
# 11     Malignant
# 360       Benign
# 74        Benign
# 293       Benign
#          ...
# 403       Benign
# 68        Benign
# 78     Malignant
# 178       Benign
# 424       Benign
# 217       Benign
# 37        Benign
# 335    Malignant
# 479    Malignant
# 533    Malignant
# 512    Malignant
# 557       Benign
# 551       Benign
# 270       Benign
# 373    Malignant
# 561       Benign
# 540       Benign
# 239    Malignant
# 411       Benign
# 342       Benign
# 528       Benign
# ...

# %%
#Fitting clasisifier ito training data
clf = neighbors.KNeighborsClassifier()
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# Predicting the test set results 
y_predict = clf.predict(x_test)

# %%
y_predict
# Out:
# array(['Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
# ...

# %%
y_test
# Out:
# 89        Benign
# 485       Benign
# 283    Malignant
# 154       Benign
# 222       Benign
# 264    Malignant
# 425       Benign
# 100    Malignant
# 447       Benign
# 389    Malignant
# 309       Benign
# 196    Malignant
# 49        Benign
# 130       Benign
# 259    Malignant
# 374       Benign
# 303       Benign
# 358       Benign
# 326       Benign
# 296       Benign
# 185       Benign
# 116       Benign
# 182    Malignant
# 201    Malignant
# 299       Benign
# 345       Benign
# 11     Malignant
# 360       Benign
# 74        Benign
# 293       Benign
#          ...
# 403       Benign
# 68        Benign
# 78     Malignant
# 178       Benign
# 424       Benign
# 217       Benign
# 37        Benign
# 335    Malignant
# 479    Malignant
# 533    Malignant
# 512    Malignant
# 557       Benign
# 551       Benign
# 270       Benign
# 373    Malignant
# 561       Benign
# 540       Benign
# 239    Malignant
# 411       Benign
# 342       Benign
# 528       Benign
# ...

# %%
#build a c,y_preonfusion matrix on test and train
from sklearn.metrics import confusion_matrix
clf_cm_test = confusion_matrix(y_test,y_predict)
clf_cm_test
# Out:
# array([[71,  2],
#        [ 3, 38]], dtype=int64)

# %%
#obtain accuracyu
accuracy = clf.score(x_test,y_test)

# %%
print(accuracy)
# Out:
# 0.956140350877193

# %%
#test new data 
example_measures=np.array([15.44,12.54,150.9,998,0.2345,0.3452,0.2891,0.1234,0.3421,0.06879,2.076,0.8079,7.274,168.7,0.009786,0.03804,0.04372,0.02785,0.02002,0.007621,28.75,16.44,192.7,2025,0.1723,0.7752,0.7121,0.3421,0.4802,0.1278])
example_measures = example_measures.reshape(1,-1)

# %%
prediction = clf.predict(example_measures)

# %%
print(prediction)
# Out:
# ['Malignant']

# %%
# perfform logistic regression
from sklearn.linear_model.logistic import LogisticRegression
cls = LogisticRegression(random_state = 0)
lr_cls = cls.fit(x_train,y_train)

# %%
#predictin go test and train dtaa
lr_y_test = lr_cls.predict(x_test)
lr_y_test
# Out:
# array(['Malignant', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Malignant',
# ...

# %%
lr_y_train = lr_cls.predict(x_train)
lr_y_train
# Out:
# array(['Benign', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
# ...

# %%
from sklearn.metrics import confusion_matrix
clf_cm_test = confusion_matrix(y_test,lr_y_test)
clf_cm_test
# Out:
# array([[61,  2],
#        [ 6, 45]], dtype=int64)

# %%
accuracy = clf.score(x_test,lr_y_test)

# %%
print(accuracy)
# Out:
# 0.9298245614035088

# %% [markdown]
# # Support Vector Classification

# %%
# support vector classification
from sklearn.svm import SVC
sc = SVC(kernel='rbf')
sc_classifier = sc.fit(x_train,y_train) #model building

# %%
#Predictong on test and train data
svc_y_test = sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# ['Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
# ...

# %%
svc_y_train = sc_classifier.predict(x_train)
print(svc_y_train)
# Out:
# ['Benign' 'Malignant' 'Malignant' 'Malignant' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign' 'Malignant'
#  'Malignant' 'Malignant' 'Malignant' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign' 'Benign' 'Malignant'
#  'Malignant' 'Malignant' 'Malignant' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign'
# ...

# %% [raw]
# # building confusion matrux on test and train
# from sklearn.metrics import confusion_matrix
# svc_cm_test = confusion_matrix(y_test,svc_y_test)
# svc_cm_test

# %%
svc_cm_train = confusion_matrix(y_train,svc_y_train)
svc_cm_train
# Out:
# array([[294,   0],
#        [  0, 161]], dtype=int64)

# %%
#accuracy classification score 
from sklearn.metrics import accuracy_score
svc_acc_test = accuracy_score(y_test,svc_y_test)  # for test
svc_acc_test
# Out:
# 0.5526315789473685

# %%
svc_acc_train = accuracy_score(y_train , svc_y_train) #for train
svc_acc_train
# Out:
# 1.0

# %% [markdown]
# # CLassification using Decision trees

# %%
# over fitting = when a  much of the data tries to behave as another data at the center the tree specially

# %%
#Decision Tree Classifier 
from sklearn.tree import DecisionTreeClassifier
dtc_clf = DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# predicting on test and train data
dtc_y_test = dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array(['Malignant', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
# ...

# %% [markdown]
# dtc_y_train = dtc_clf.predict(x_train)
# dtc_y_train

# %%
# buildind the confusion matrix
from sklearn.metrics import confusion_matrix 
dtc_cm_test = confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[59,  4],
#        [ 9, 42]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
dtc_accu_test = accuracy_score(y_test,dtc_y_test)
dtc_accu_test
# Out:
# 0.8859649122807017

# %%
# take an excel sheet of training and test data

# %% [markdown]
# # Ranodm Forest Classifier

# %%
#Builds Random  Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

# %%
rmf = RandomForestClassifier(max_depth = 3 , random_state = 0)
rf_classi = rmf.fit(x_train,y_train)

# %%
# pedicting on the test and trian data
rf_y_test  =rf_classi.predict(x_test)
rf_y_test
# Out:
# array(['Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
# ...

# %%
rf_y_train = rf_classi.predict(x_train)
rf_y_train
# Out:
# array(['Malignant', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
# ...

# %%
# buliding the confudion matrix
from sklearn.metrics import confusion_matrix
rf_cm_test = confusion_matrix(y_test,rf_y_test)
rf_cm_test
# Out:
# array([[71,  2],
#        [ 4, 37]], dtype=int64)

# %%
rf_cm_train = confusion_matrix(y_train,rf_y_train)
rf_cm_train
# Out:
# array([[282,   2],
#        [ 10, 161]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_accu_test  = accuracy_score(y_test,rf_y_test)   # test
rf_accu_test
# Out:
# 0.9473684210526315

# %%
rf_accu_train  = accuracy_score(y_train,rf_y_train)   # test
rf_accu_train
# Out:
# 0.9736263736263736

# %%
#Pecision Score on tets and training dataa
from sklearn.metrics import precision_score
rf_precision_test = precision_score(y_test ,rf_y_test , average = 'weighted')
print(rf_precision_test)
rf_precision_train = precision_score(y_train ,rf_y_train , average = 'weighted')
print(rf_precision_train)
# Out:
# 0.9474044084570401
# 0.9740127760297522

# %%
from sklearn.metrics import recall_score
rf_recall_test = recall_score(y_test,rf_y_test ,average ='weighted')
print(rf_recall_test)
rf_recall_train = recall_score(y_train,rf_y_train ,average ='weighted')
print(rf_recall_train)
# Out:
# 0.9473684210526315
# 0.9736263736263736

# %% [markdown]
# # AdaBoost : adaptive boosting

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
seed = 7
num_trees = 30
kfold = model_selection.KFold(n_splits = 10,random_state = seed)
model = AdaBoostClassifier(n_estimators=num_trees,random_state = seed)
results = model_selection.cross_val_score(model,x_train,y_train,cv=kfold)

# %%
results
# Out:
# array([0.95652174, 0.97826087, 0.93478261, 0.93478261, 1.        ,
#        0.95555556, 0.95555556, 0.93333333, 0.95555556, 0.97777778])

# %%
results.mean()
# Out:
# 0.9582125603864735
